# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
from multiprocessing import Pool
from sklearn.feature_extraction.text import CountVectorizer

# %%
urls = []
page_num = 1
while True:
    r = requests.get("http://devpost.com/software/popular?query=is%3Afeatured&page=" + str(page_num))
    soup = BeautifulSoup(r.text, "lxml")
    projects = soup.findAll("div", {"class": "gallery-item"})
    if len(projects) == 0:
        break
    for i in projects:
        urls.append(i.find("a")['href'])
    page_num += 1

# %%
def parse_post(url):    
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    header = soup.find("header", {"id": "software-header"})
    title = ''
    title_tag = header.find("h1", {"id": "app-title"})
    if title is not None:
        title = title_tag.text
    subtitle = ''
    subtitle_tag = header.find("p", {"class": "large"})
    if subtitle_tag is not None:
        subtitle = subtitle_tag.text
    like_button = header.find("a", {"class": "like-button"})
    like_count = like_button.find("span", {"class": "side-count"}).text
    built_with = soup.find("div", {"id": "built-with"})
    categories = []
    if built_with is not None:
        for i in built_with.findAll("li"):
            span = i.find("span")
            if span is not None:
                categories.append(span.text)
        
    software_lh = soup.find("div", {"class": "software-list-content"})
    hackathon = ''
    winnings = []
    if software_lh is not None:
        hackathon = software_lh.find("a").text
        winnings = []
        prizes = software_lh.findAll("li")
        for i in prizes:
            winnings.append(i.text)
            
    body = soup.find("div", {"id": "app-details-left"})
    description = ''
    if body is not None:
        parts = []
        for h2, p in zip(a.findAll("h2"), a.findAll("p")):
            parts.append(h2.text)
            parts.append(p.text)
        descriptions = "\n".join(parts)
        
    app_team = soup.find("section", {"id": "app-team"})
    if app_team is not None:
        for i in app_team.findAll("a"):
            
        
    return {
        "title": title,
        "subtitle": subtitle,
        "like_count": like_count,
        "categories": categories,
        "hackathon": hackathon,
        "winnings": winnings,
        'description': description,
    }

# %%
a=parse_post(urls[1])

# %%
a[3].text
# Out:
# 'Will Zhang'

# %%
p = Pool(5)
data = p.map(parse_post, urls)
    
with open("data.json", "w") as f:
    f.write(json.dumps(data))

# %%
df = pd.read_json("./data.json")

# %%
def clean_winnings(s):
    s = s.replace("\n", "")
    s = s.replace("Winner", "")
    s = s.strip()
    return s

# %%
df['winnings'] = df['winnings'].apply(lambda x: list(map(clean_winnings, x)))

# %%
def isWinner(df):
    df['winnings'] = df['winnings'].apply(lambda x: len(x) > 0)
    return df

# %%
df = isWinner(df)

# %%
df['num_cat'] = df['categories'].apply(lambda x: len(x))
df['like_count'] = df['like_count'].astype(int)

# %%
df
# Out:
#                                             categories  \
# 0             [microsoft-hololens, unity, c#, blender]
# 1       [leap-motion, raspberry-pi, servo, 3dprinting]
# 2                                             [matlab]
# 3           [c++, python, svo, imu, makerbot, ps3-eye]
# 4    [watson-tone-analyzer, bark.us-api, python, ja...
# 5                                  [arduino, 3d-print]
# 6    [javascript, jquery, python, postgresql, machi...
# 7    [arduino, swift, innovation, cardboard, duct-t...
# 8       [javascript, node.js, unity, c#, amazon-alexa]
# 9    [ios, python, firebase, swift, c.h.i.p., 3dpri...
# 10                 [amazon-alexa, javascript, node.js]
# 11                                               [ios]
# 12   [pepper, softbank, ibm-watson, braintree, java...
# 13                      [react.js, panasonic-avionics]
# 14                                  [processing, java]
# 15                                     [java, android]
# 16                                                  []
# 17                      [swift, html, css, mysql, php]
# 18   [javascript, html, python, css, blender, math,...
# 19                          [wxpython, python, opencv]
# 20   [javascript, java, leap-motion, android, chrom...
# 21   [heroku, node.js, python, amazon-alexa, amazon...
# 22   [html5, css, javascript, json, sketch-app, chr...
# 23   [android, python, flask, javascript, html5, cs...
# 24   [python, raspberry-pi, arduino, html5, css3, j...
# 25                                            [python]
# 26   [mongodb, react, objective-c, sinch, iphone-sd...
# 27                           [swift, sketch, estimote]
# 28                            [opencv, unity, c++, c#]
# 29   [arduino, 3dprinting, soildworks, simplify-3d,...
# ..                                                 ...
# 475                                  [foursquare, ios]
# 476  [python, javascript, localforage, chrome, giph...
# 477  [last.fm, bootstrap, jquery, javascript, html,...
# 478                                      [sketch, ios]
# 479  [pebble, dominos, pizza, javascript, c, androi...
# 480          [python, ritetag, requests, mac, windows]
# 481                [php, bootstrap, font-awesome, web]
# 482          [jquery, wordpress, php, javascript, web]
# 483  [arduino, windows, python, unity, oculus, hard...
# 484  [adobe-illustrator, javascript, tresensa, tge,...
# 485  [particle, android, firebase, microwave, c#, p...
# 486            [spotify, applescript, shell, git, mac]
# 487  [intel-xdk, alchemyapi, google-app-engine, ink...
# 488  [leap-motion, javascript, jquery, 2048, hardwa...
# 489                                              [web]
# 490  [arduino, opencv, tesseract, python, hardware,...
# 491  [objective-c, filepicker.io, blood, sweat, tea...
# 492  [ios, allareacodes, mongodb, python, nexmo, an...
# 493                                                 []
# 494  [stripe, mongodb, sendgrid, lob, namecheap, go...
# 495                                [android, hardware]
# 496  [xcode, facebook-graph, weather-underground, p...
# 497      [google-app-engine, google-maps, twilio, web]
# 498  [angular.js, javascript, leap-motion, node.js,...
# 499                                                 []
# 500  [ruby-on-rails, javascript, jquery, zurb-found...
# 501  [bootstrap, jquery, javascript, bit.ly, zerocl...
# 502  [twilio, domainr, bootstrap, font-awesome, bit...
# 503  [bootstrap, font-awesome, javascript, jquery, ...
# 504  [bootstrap, font-awesome, javascript, jquery, ...
#
#                                 hackathon  like_count  \
# 0           Reality, Virtually, Hackathon          10
# 1                            HackUMass IV           7
# 2                       HackUPC Fall 2016           6
# 3                                MHacks 8           3
# 4                       HackDartmouth III           4
# 5                             HackGT 2016           4
# 6                  Predix India Hackathon          10
# 7                            HackCMU 2016          20
# 8                     Hack the North 2016           8
# 9                     Hack the North 2016           6
# 10                                HackISU           5
# 11                           PennApps XIV           7
# 12             TechCrunch Disrupt SF 2016           6
# 13             TechCrunch Disrupt SF 2016           8
# 14                     Fall HackMTY 2016            7
# 15                            CHIMEHACK 3           7
# 16               Android Summit Hackathon           7
# 17                    UHack Tasmania 2016           3
# 18                          Hack The 6ix            3
# 19                          Hack the Heat           3
# 20                              InOut 3.0          12
# 21                       Open Source Hack          12
# 22           MLH Prime Spring Finale 2016          10
# 23           MLH Prime Spring Finale 2016           7
# 24           MLH Prime Spring Finale 2016           4
# 25                 School's Out Hackathon           3
# 26                           UNIHACK 2016           7
# 27                           UNIHACK 2016           4
# 28                           UNIHACK 2016           4
# 29                           UNIHACK 2016           4
# ..                                    ...         ...
# 475       TechCrunch Disrupt NY Hackathon           6
# 476                                                 8
# 477                                                 3
# 478  Tech Triangle U Mentorship Hackathon           4
# 479                      HackBU Hackathon           2
# 480                                                 2
# 481                                                 2
# 482                                                 2
# 483                LA Hacks - Spring 2014           3
# 484                 Spring Break Game Jam           3
# 485                          HackIllinois           2
# 486                                                 4
# 487             HackPrinceton Spring 2014           6
# 488             HackPrinceton Spring 2014           2
# 489             HackPrinceton Spring 2014           2
# 490                  PennApps Spring 2014          15
# 491                    MHacks Winter 2014           9
# 492                  PennApps Spring 2014           4
# 493                                MHacks           6
# 494                    MHacks Winter 2014           5
# 495                  PennApps Spring 2014           4
# 496                    MHacks Winter 2014           2
# 497                  PennApps Spring 2014           2
# 498                  PennApps Spring 2014           2
# 499                                MHacks           2
# 500                                                13
# 501                                                 4
# 502                                                 5
# 503                                                 3
# 504                                                 2
#
#                                               subtitle  \
# 0                         \n    Choose Your Flavor\n
# 1    \n    Move a ball through a maze without touch...
# 2    \n    Take the best images automaticly, in sec...
# 3    \n    A personal ping pong trainer in the palm...
# 4    \n    SurfShield is an extension for Chrome, a...
# 5    \n    Automatically locking knee brace - when ...
# 6    \n     Ultimate health care tool for predictin...
# 7    \n    Have you ever been starving after classe...
# 8    \n    VR Open Heart Surgery With Alexa as a Vi...
# 9    \n    Self learning a string instrument is dif...
# 10   \n    Do away with those annoying keys and unl...
# 11   \n    Cheap eye exams for third world countrie...
# 12   \n    The fun way to buy goods from your favor...
# 13   \n    Intelligent virtual flight attendant tha...
# 14   \n    Genetic algorithm to increase traffic li...
# 15   \n    Autochime automatically reacts to violen...
# 16   \n    Find yourself a home within your means w...
# 17   \n    Darcy's World Domination Hacktastic Spec...
# 18   \n    A web service to perfectly and dynamical...
# 19   \n    Use your hands, face, eyes or a sticky n...
# 20   \n    LeapDrop is a hack that allows the geek ...
# 21   \n    Talking instead of typing WhatsApp messa...
# 22   \n    React to videos in real time with the wo...
# 23   \n    PetControl enables you to keep an eye on...
# 24   \n    A fun and interactive way of experiencin...
# 25   \n    Network administrator's new tool to scan...
# 26   \n    Connecting customers and shops instantly...
# 27      \n    Live patient information for doctors\n
# 28   \n    An app that shows you how to solve a pyr...
# 29                \n    It does make a difference.\n
# ..                                                 ...
# 475  \n    An entirely new way to capture, remember...
# 476                \n    Poncho - in your Browser!\n
# 477  \n    Muap - let your friends bring the good m...
# 478              \n    A beautiful dimsum handbook\n
# 479           \n    Order pizza using your Pebble!\n
# 480  \n    Query the RiteTag API for a list of rele...
# 481                 \n    résumés that don't suck!\n
# 482  \n    Place ads in between comments on your se...
# 483                                  \n    Tagline\n
# 484
# 485
# 486  \n    Add Spotify status to git commit message...
# 487
# 488  \n    Play a 2048 clone with your Leap Motion!...
# 489  \n    Two factor authentication via facial map...
# 490
# 491        \n    Desktop Productivity on your iPad\n
# 492
# 493
# 494
# 495
# 496
# 497
# 498
# 499
# 500  \n    A partnership between the public and the...
# 501  \n    Add Google Analytics UTM tags to your UR...
# 502  \n    Check domain name availability via SMS!\n
# 503  \n    'Proximity search' webapp for reviewing ...
# 504  \n    Entry / Exit traffic charts for NYC subw...
#
#                                                  title winnings  num_cat
# 0                                          Fizz Filter    False        4
# 1                                       Jedi Maze Game    False        4
# 2                                              ImaTake     True        1
# 3                                     Stroke of Genius    False        6
# 4                                           SurfShield     True       14
# 5                                          IntelliKnee    False        2
# 6    Trojan - Automated Diabetic Retinopathy Detection    False       14
# 7                                          Bob's Ramen     True        6
# 8                                   Project Open Heart     True        5
# 9                                            UkeMaster    False       10
# 10                                           Talk Lock    False        3
# 11                                               Theia     True        1
# 12                                           PepperPay     True        8
# 13                                               Panny    False        2
# 14                                       Smart Traffic    False        2
# 15                                           autochime    False        2
# 16                                              Hinder     True        0
# 17              Darcy's World Domination: Shar-Animals    False        5
# 18                                      3DModelResizer     True        7
# 19                                       Beat the Box!     True        3
# 20                                            LeapDrop    False        7
# 21                                    Talking WhatsApp    False        6
# 22                                    Watch With World     True        9
# 23                                          PetControl     True        7
# 24                                             Chess++     True        9
# 25                                       Scan 'n' Grab     True        1
# 26                                          PocketShop    False        9
# 27                                            DOChuman    False        3
# 28                                     Pyraminx Scheme     True        4
# 29                                      The Magic Hand     True        7
# ..                                                 ...      ...      ...
# 475                         Indulge: The Nail Snob App     True        2
# 476                                      Poncho Chrome    False        6
# 477                                              Muap!    False        8
# 478                                            Shoomai     True        2
# 479                                           Pizzable    False       11
# 480                                           ritehash    False        5
# 481                                         BootResume    False        4
# 482                                          ScrollPop    False        5
# 483        Tred - Virtual Reality Immersion Experience     True        6
# 484                                        ColorChase      True        6
# 485                                           nextWAVE     True       10
# 486                                            SpotGIT    False        5
# 487                                             Lektur    False        5
# 488                                             Leap64    False        7
# 489                                             Sphinx     True        1
# 490                               The Homework Machine     True        7
# 491                                           Workflow     True        6
# 492                                         Smart Send     True       11
# 493                                           GreenCan     True        0
# 494                                          PostPushr     True       14
# 495                                        Smack That!    False        2
# 496                                          High Five    False       10
# 497                                              HUber    False        4
# 498                               Bop It x Leap Motion    False       12
# 499                                          Follow Me    False        0
# 500                                      Challenge.gov    False        6
# 501                                       UTM Bossmode    False        9
# 502                                             WhoSMS    False       12
# 503                                          LegalGrep    False        6
# 504                              MTA Turnstile Traffic    False       12
#
# [505 rows x 7 columns]
